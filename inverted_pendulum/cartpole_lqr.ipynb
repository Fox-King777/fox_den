# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import gym
import linear_quadratic_regulator as lqr

# %%
# get environment
env = gym.make('CartPole-v1', render_mode='human')
env.reset(options={'low': -0.3, 'high': 0.3})
env.theta_threshold_radians = 24 * 2 * 3.14159265359 / 360

# print environment parameters
print('Environment parameters:')
print('Gravity: ', env.gravity)
print('Mass of the cart: ', env.masscart)
print('Mass of the pole: ', env.masspole)
print('Total mass: ', env.total_mass)
print('Length of the pole: ', env.length)
print('Pole mass length: ', env.polemass_length)
print('Force: ', env.force_mag)
print('Theta threshold: ', env.theta_threshold_radians)
print('X threshold: ', env.x_threshold)
# Out:
# Environment parameters:
# Gravity:  9.8
# Mass of the cart:  1.0
# Mass of the pole:  0.1
# Total mass:  1.1
# Length of the pole:  0.5
# Pole mass length:  0.05
# Force:  10.0
# Theta threshold:  0.4188790204786667
# X threshold:  2.4

# %%
lqr.run_linear_quadratic_regulator(env, 400)
